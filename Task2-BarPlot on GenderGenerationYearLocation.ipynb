# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

import pandas as pd
#import csv
year_data = pd.read_csv(r".\\CSV Files\\Year_of_Narrator.csv")
#data.head()
#data.info()
year_data = year_data.dropna() 

#data[["Year"]].astype(int64)
year_data['Year'] = year_data['Year'].astype('int64').astype('str')

year_data = year_data.sort_values(by=['Year'], ascending=True)
print(year_data.head())
# Out:
#              Narrator  Year
# 282  Yukio Kawaratani  1031
# 637      Floyd Schmoe  1895
# 411         Rin Miura  1901
# 392      Tom Matsuoka  1903
# 30   Yone Bartholomew  1904

# %%
plt.rcParams['figure.figsize'] = [30, 15]
ax = sns.countplot(x='Year', data=year_data)
ax.bar_label(ax.containers[0])
plt.xlabel("Year of Birth of Narrator")
plt.ylabel("Count of Years")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Barplot on Location of Narrators

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns
import pandas as pd
#import csv
location_data = pd.read_csv(r".\\CSV Files\\Location_of_Narrator.csv")
#data.head()
#data.info()
location_data = location_data.dropna()
#print(data.head())

#data['Year'] = data['Year'].astype('int64')
#plt.rcParams['figure.figsize'] = [15, 20]
#print(data['Location'].value_counts().plot(kind='bar',figsize=(15, 20), xlabel = 'Birth Location of Narrators', ylabel = 'Count', rot= 90))
plt.rcParams['figure.figsize'] = [30, 15]
ax = sns.countplot(x='Location', data=location_data)
ax.bar_label(ax.containers[0])
plt.xlabel("Location of Birth of Narrator")
plt.ylabel("Count of Locations")
plt.xticks(rotation=90)
plt.show()

# %%
location_data
# Out:
#                   Narrator    Location
# 0             Kay Aiko Abe  Washington
# 1                  Art Abe  Washington
# 2    Sharon Tanagi Aburano  Washington
# 3          Toshiko Aiboshi  California
# 4               Yae Aihara  Washington
# ..                     ...         ...
# 898       George Yoshinaga  California
# 899      George M. Yoshino  Washington
# 900             John Young  California
# 901            Sharon Yuen  Washington
# 903            Aaron Zajic    Maryland
#
# [832 rows x 2 columns]

# %% [markdown]
# # Barplot on Generation of Narrators

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

import pandas as pd
#import csv
generation_data = pd.read_csv(r".\\CSV Files\\Generation_Gender_of_Narrator.csv")
#data.head()
#data.info()
generation_data = generation_data.dropna()
#(data.head())

#data['Year'] = data['Year'].astype('int64')
#plt.rcParams['figure.figsize'] = [15, 20]
#print(generation_data['Generation'].value_counts().plot(kind='bar',figsize=(15, 20), xlabel = 'Generation of Narrators', ylabel = 'Count', rot= 90))
#plt.show()
plt.rcParams['figure.figsize'] = [20, 15]
ax = sns.countplot(x='Generation', data=generation_data)
ax.bar_label(ax.containers[0])
plt.xlabel("Generation of Narrator")
plt.ylabel("Count of Generations")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Barplot on Genders of Narrators

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

import pandas as pd
#import csv
gender_data = pd.read_csv(r".\\CSV Files\\Generation_Gender_of_Narrator.csv")
#data.head()
#data.info()
gender_data = generation_data.dropna()
#(data.head())

#data['Year'] = data['Year'].astype('int64')
#plt.rcParams['figure.figsize'] = [15, 20]
#print(generation_data['Generation'].value_counts().plot(kind='bar',figsize=(15, 20), xlabel = 'Generation of Narrators', ylabel = 'Count', rot= 90))
#plt.show()
plt.rcParams['figure.figsize'] = [5,5]
ax = sns.countplot(x='Gender', data=generation_data)
ax.bar_label(ax.containers[0])
plt.xlabel("Gender of Narrator")
plt.ylabel("Count of Gender")
plt.xticks(rotation=90)
plt.show()
